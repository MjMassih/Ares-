# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import yfinance as yf

# %%
apple = yf.Ticker("BTC-USD")

# %%
# Get the most current price available (15-20 min delayed)

# Method 1: fast_info - Fastest way to get current price
current_price_fast = apple.fast_info['lastPrice']
print(f"Fast Info - Last Price: ${current_price_fast:.2f}")
# Out:
# Fast Info - Last Price: $68458.00

# %%
btc = yf.Ticker("BTC-USD")
btc_price = btc.history(period="1d")["Close"]

# %%
btc_price
# Out:
# Date
# 2026-02-16 00:00:00+00:00    68488.539062
# Name: Close, dtype: float64
